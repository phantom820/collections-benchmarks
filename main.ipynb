# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import glob
import seaborn as sns
sns.set_theme(style="whitegrid")

# %%
COLUMNS = ['Collection','Operation','Time(ns)']

# %%
def loadFile(fname):
    df = pd.read_csv(fname,names=COLUMNS)
    df['Time(ms)']  = df['Time(ns)']*1e-6
    return df

def loadFiles(path):
    data = []
    fnames = glob.glob(path)
    for fname in fnames:
        data.append(loadFile(fname))
    return pd.concat(data)

# %%
lists = loadFile('lists.csv')
sets = loadFile('sets.csv')
queues = loadFile('queues.csv')
sets_lists = pd.concat([lists,sets])
lists
# Out:
#      Collection   Operation      Time(ns)     Time(ms)
# 0   ForwardList         Add  2.955026e+06     2.955026
# 1          List         Add  3.188955e+06     3.188955
# 2        Vector         Add  2.994225e+06     2.994225
# 3   ForwardList    Contains  2.335762e+09  2335.762400
# 4          List    Contains  2.367416e+09  2367.416300
# 5        Vector    Contains  2.520993e+09  2520.992800
# 6   ForwardList      Remove  3.314723e+09  3314.723300
# 7          List      Remove  2.132493e+09  2132.493200
# 8        Vector      Remove  2.352187e+09  2352.187100
# 9   ForwardList  RemoveBack  1.279162e+09  1279.162500
# 10         List  RemoveBack  1.100305e+05     0.110030
# 11       Vector  RemoveBack  2.845150e+05     0.284515
# 12  ForwardList    RemoveAt  7.262952e+08   726.295200
# 13         List    RemoveAt  1.840215e+09  1840.214800
# 14       Vector    RemoveAt  9.785394e+07    97.853944
# 15  ForwardList    Iterator  6.390000e+02     0.000639
# 16         List    Iterator  5.710000e+02     0.000571
# 17       Vector    Iterator  8.060000e+02     0.000806
# 18  ForwardList     Reverse  1.234345e+05     0.123434
# 19         List     Reverse  1.122690e+05     0.112269
# 20       Vector     Reverse  7.969300e+04     0.079693
# 21  ForwardList        Sort  7.163042e+06     7.163042
# 22         List        Sort  7.815476e+06     7.815476
# 23       Vector        Sort  6.681845e+06     6.681845

# %% [markdown]
# ### Lists

# %%
ax = plt.figure(figsize=(15,12))
lists.groupby(['Collection','Operation'])['Time(ms)'].mean().unstack().plot.barh(subplots=True,ax=ax,width=.3)
ax.tight_layout()
# Out:
# /tmp/ipykernel_639629/401160910.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   lists.groupby(['Collection','Operation'])['Time(ms)'].mean().unstack().plot.barh(subplots=True,ax=ax,width=.3)

# %% [markdown]
# ### Sets

# %%
ax = plt.figure(figsize=(15,10))
sets.groupby(['Collection','Operation'])['Time(ms)'].mean().unstack().plot.barh(subplots=True,ax=ax,width=.3)
ax.tight_layout()
# Out:
# /tmp/ipykernel_639629/214010595.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   sets.groupby(['Collection','Operation'])['Time(ms)'].mean().unstack().plot.barh(subplots=True,ax=ax,width=.3)

# %% [markdown]
# ### Lists & Sets

# %%
ax = plt.figure(figsize=(15,20))
sets_lists.groupby(['Collection','Operation'])['Time(ms)'].mean().unstack().plot.barh(subplots=True,ax=ax,width=.3)
ax.tight_layout()
# Out:
# /tmp/ipykernel_639629/1444417774.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   sets_lists.groupby(['Collection','Operation'])['Time(ms)'].mean().unstack().plot.barh(subplots=True,ax=ax,width=.3)

# %% [markdown]
# ### Queues

# %%
ax = plt.figure(figsize=(15,10))
queues.groupby(['Collection','Operation'])['Time(ms)'].mean().unstack().plot.barh(subplots=True,ax=ax,width=.3)
ax.tight_layout()
# Out:
# /tmp/ipykernel_639629/81923308.py:2: UserWarning: To output multiple subplots, the figure containing the passed axes is being cleared.
#   queues.groupby(['Collection','Operation'])['Time(ms)'].mean().unstack().plot.barh(subplots=True,ax=ax,width=.3)
